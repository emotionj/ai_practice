# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pd.read_csv('/content/drive/MyDrive/Classroom/인공지능 서비스 개발자 _ 강동1기/code/과제/5_crime_20221226100947.csv', thousands=',')
# Out:
#     자치구별(1)  자치구별(2)   2021 2021.1 2021.2 2021.3 2021.4 2021.5   2021.6  \
# 0   자치구별(1)  자치구별(2)     합계     합계     합계     합계     합계     합계       합계
# 1   자치구별(1)  자치구별(2)     소계     소계     살인     살인     강도     강도  강간·강제추행
# 2   자치구별(1)  자치구별(2)     발생     검거     발생     검거     발생     검거       발생
# 3        합계       소계  80445  58012    124    112    122    116     4911
# 4        합계      종로구   2712   2755      6      3      4      4      156
# 5        합계       중구   2861   2072      6      6      6      6      161
# 6        합계      용산구   2381   1659      3      2      1      1      141
# 7        합계      성동구   2112   1510      3      4      4      1      110
# 8        합계      광진구   3087   2202      5      3      4      4      208
# 9        합계     동대문구   2959   2113      3      4      7      8      169
# 10       합계      중랑구   3210   2405      4      4      6      7      141
# 11       합계      성북구   2411   1787      4      3      2      2      118
# ...

# %%
crime_raw_data = pd.read_csv('/content/drive/MyDrive/Classroom/인공지능 서비스 개발자 _ 강동1기/code/과제/5_crime_20221226100947.csv', thousands=',')

# %%
crime_raw_data.head(3)
# Out:
#    자치구별(1)  자치구별(2) 2021 2021.1 2021.2 2021.3 2021.4 2021.5   2021.6   2021.7  \
# 0  자치구별(1)  자치구별(2)   합계     합계     합계     합계     합계     합계       합계       합계
# 1  자치구별(1)  자치구별(2)   소계     소계     살인     살인     강도     강도  강간·강제추행  강간·강제추행
# 2  자치구별(1)  자치구별(2)   발생     검거     발생     검거     발생     검거       발생       검거
#
#   2021.8 2021.9 2021.10 2021.11
# 0     합계     합계      합계      합계
# 1     절도     절도      폭력      폭력
# 2     발생     검거      발생      검거

# %%
crime_raw_data.dtypes
# Out:
# 자치구별(1)    object
# 자치구별(2)    object
# 2021       object
# 2021.1     object
# 2021.2     object
# 2021.3     object
# 2021.4     object
# 2021.5     object
# 2021.6     object
# 2021.7     object
# 2021.8     object
# 2021.9     object
# 2021.10    object
# 2021.11    object
# dtype: object

# %%
crime_raw_data[1:]
# Out:
#     자치구별(1)  자치구별(2)   2021 2021.1 2021.2 2021.3 2021.4 2021.5   2021.6  \
# 1   자치구별(1)  자치구별(2)     소계     소계     살인     살인     강도     강도  강간·강제추행
# 2   자치구별(1)  자치구별(2)     발생     검거     발생     검거     발생     검거       발생
# 3        합계       소계  80445  58012    124    112    122    116     4911
# 4        합계      종로구   2712   2755      6      3      4      4      156
# 5        합계       중구   2861   2072      6      6      6      6      161
# 6        합계      용산구   2381   1659      3      2      1      1      141
# 7        합계      성동구   2112   1510      3      4      4      1      110
# 8        합계      광진구   3087   2202      5      3      4      4      208
# 9        합계     동대문구   2959   2113      3      4      7      8      169
# 10       합계      중랑구   3210   2405      4      4      6      7      141
# 11       합계      성북구   2411   1787      4      3      2      2      118
# 12       합계      강북구   2301   1912      4      4      1      1      136
# ...

# %%
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구별(1)  29 non-null     object
#  1   자치구별(2)  29 non-null     object
#  2   2021     29 non-null     object
#  3   2021.1   29 non-null     object
#  4   2021.2   29 non-null     object
#  5   2021.3   29 non-null     object
#  6   2021.4   29 non-null     object
#  7   2021.5   29 non-null     object
#  8   2021.6   29 non-null     object
#  9   2021.7   29 non-null     object
#  10  2021.8   29 non-null     object
#  11  2021.9   29 non-null     object
#  12  2021.10  29 non-null     object
#  13  2021.11  29 non-null     object
# dtypes: object(14)
# memory usage: 3.3+ KB

# %%
crime_raw_data['자치구별(2)'].unique()[2:]
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
crime_raw_data.columns=['합계','자치구','발생합계','검거합계','살인발생','살인검거','강도발생','강도검거','강간강제추행발생','강간강제추행검거','절도발생','절도검거','폭력발생','폭력검거']

# %%
crime_raw_data
# Out:
#          합계      자치구   발생합계   검거합계 살인발생 살인검거 강도발생 강도검거 강간강제추행발생 강간강제추행검거  \
# 0   자치구별(1)  자치구별(2)     합계     합계   합계   합계   합계   합계       합계       합계
# 1   자치구별(1)  자치구별(2)     소계     소계   살인   살인   강도   강도  강간·강제추행  강간·강제추행
# 2   자치구별(1)  자치구별(2)     발생     검거   발생   검거   발생   검거       발생       검거
# 3        합계       소계  80445  58012  124  112  122  116     4911     4446
# 4        합계      종로구   2712   2755    6    3    4    4      156      757
# 5        합계       중구   2861   2072    6    6    6    6      161       97
# 6        합계      용산구   2381   1659    3    2    1    1      141      103
# 7        합계      성동구   2112   1510    3    4    4    1      110       82
# 8        합계      광진구   3087   2202    5    3    4    4      208      161
# 9        합계     동대문구   2959   2113    3    4    7    8      169      147
# 10       합계      중랑구   3210   2405    4    4    6    7      141      117
# 11       합계      성북구   2411   1787    4    3    2    2      118       88
# ...

# %%
set_crime=crime_raw_data[4:]

# %%
set_crime['자치구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
set_crime['자치구'].nunique()
# Out:
# 25

# %%
set_crime['자치구'].notnull()
# Out:
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# Name: 자치구, dtype: bool

# %%
set_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 4 to 28
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   합계        25 non-null     object
#  1   자치구       25 non-null     object
#  2   발생합계      25 non-null     object
#  3   검거합계      25 non-null     object
#  4   살인발생      25 non-null     object
#  5   살인검거      25 non-null     object
#  6   강도발생      25 non-null     object
#  7   강도검거      25 non-null     object
#  8   강간강제추행발생  25 non-null     object
#  9   강간강제추행검거  25 non-null     object
#  10  절도발생      25 non-null     object
#  11  절도검거      25 non-null     object
#  12  폭력발생      25 non-null     object
#  13  폭력검거      25 non-null     object
# dtypes: object(14)
# memory usage: 2.9+ KB

# %%
set_crime
# Out:
#     합계   자치구  발생합계  검거합계 살인발생 살인검거 강도발생 강도검거 강간강제추행발생 강간강제추행검거  절도발생  절도검거  \
# 4   합계   종로구  2712  2755    6    3    4    4      156      757  1079   743
# 5   합계    중구  2861  2072    6    6    6    6      161       97  1279   739
# 6   합계   용산구  2381  1659    3    2    1    1      141      103   945   484
# 7   합계   성동구  2112  1510    3    4    4    1      110       82   905   497
# 8   합계   광진구  3087  2202    5    3    4    4      208      161  1414   754
# 9   합계  동대문구  2959  2113    3    4    7    8      169      147  1240   659
# 10  합계   중랑구  3210  2405    4    4    6    7      141      117  1399   835
# 11  합계   성북구  2411  1787    4    3    2    2      118       88   895   474
# 12  합계   강북구  2301  1912    4    4    1    1      136      115   777   537
# 13  합계   도봉구  1860  1294    2    2    2    1       72       64   772   376
# 14  합계   노원구  3425  2302    6    6    3    3      156      126  1361   654
# ...
